# %% [markdown]
# <a href="https://colab.research.google.com/github/ashfianeha/AUW-CTP-C-Fundamentals-230063/blob/main/Ashfia_230063_Continuous%20Assessment-1(S2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welcome to python basics")
#this code prints welcome message
# Out:
# welcome to python basics
